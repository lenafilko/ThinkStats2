# %%
#https://pythonprogramming.net/twitter-api-streaming-tweets-python-tutorial/
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
##import MySQLdb
##import time
import json
import sentiment_mod as s  #we should 


#        replace mysql.server with "localhost" if you are running via your own server!
#                        server       MySQL username	MySQL pass  Database name.
##conn = MySQLdb.connect("mysql.server","beginneraccount","cookies","beginneraccount$tutorial")

##c = conn.cursor()


#consumer key, consumer secret, access token, access secret.
ckey="asdfsafsafsaf"
csecret="asdfasdfsadfsa"
atoken="asdfsadfsafsaf-asdfsaf"
asecret="asdfsadfsadfsadfsadfsad"

##from twitterapistuff import *  #save your stream into the file twitterapistuff.py  before importing data from it here

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        
        tweet = all_data["text"]
        sentiment_value, confidence = s.sentiment(tweet)
        
##        username = all_data["user"]["screen_name"]
        
##        c.execute("INSERT INTO taula (time, username, tweet) VALUES (%s,%s,%s)",
##            (time.time(), username, tweet))

##        conn.commit()

##        print((username,tweet))
        print(tweet,sentiment_value, confidence)
    if confidence*100 >=80:
        output = oprn("twitter_out.txt","a")
        output.write(sentiment_value)
        output.write('\n')
        output.close()
        
        
        time.sleep(0.3)
        return True

    def on_error(self, status):
        print (status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["car"])
